# %% [markdown]
# # An Introduction to the Amazon SageMaker IP Insights Algorithm
# #### Unsupervised anomaly detection for susicipous IP addresses
# -------
# 1. [Introduction](#Introduction)
# 2. [Setup](#Setup)
# 3. [Training](#Training)
# 4. [Inference](#Inference)
# 5. [Epilogue](#Epilogue)
#
# ## Introduction
# -------
#
# The Amazon SageMaker IP Insights algorithm uses statistical modeling and neural networks to capture associations between online resources (such as account IDs or hostnames) and IPv4 addresses. Under the hood, it learns vector representations for online resources and IP addresses. This essentially means that if the vector representing an IP address and an online resource are close together, then it is likey for that IP address to access that online resource, even if it has never accessed it before.
#
# In this notebook, we use the Amazon SageMaker IP Insights algorithm to train a model on synthetic data. We then use this model to perform inference on the data and show how to discover anomalies. After running this notebook, you should be able to:
#
# - obtain, transform, and store data for use in Amazon SageMaker,
# - create an AWS SageMaker training job to produce an IP Insights model,
# - use the model to perform inference with an Amazon SageMaker endpoint.
#
# If you would like to know more, please check out the [SageMaker IP Inisghts Documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/ip-insights.html).
#
# ## Setup
# ------
# *This notebook was tested in Amazon SageMaker Studio on a ml.t3.medium instance with Python 3 (Data Science) kernel.*
#
# Our first step is to setup our AWS credentials so that AWS SageMaker can store and access training data and model artifacts.
#
# ### 1. Select Amazon S3 Bucket
# We first need to specify the locations where we will store our training data and trained model artifacts. ***This is the only cell of this notebook that you will need to edit.*** In particular, we need the following data:
#
# - `bucket` - An S3 bucket accessible by this account.
# - `prefix` - The location in the bucket where this notebook's input and output data will be stored. (The default value is sufficient.)

# %% [markdown]
# **Note: Please ensure that the following pre-requisite are set-up. For Instruction, please check with your instructor**
# 1. Create IAM Role
# 2. Create S3 Bucket
# 3. Create SageMaker Notebook Instance

# %% [markdown]
# **Step 1.1: Verify that Execution Role is set.**

# %%
# Set Variable Used below
# Set S3 Bucket Name
bucket = "aseansecaiml-25apr2023"

# Set Execution Role
from sagemaker import get_execution_role

role = get_execution_role()
print(f"Execution role set: {role}")
# Out:
# Execution role set: arn:aws:iam::817562650497:role/service-role/SageMaker-DataScientist

# %% [markdown]
# **Step 1.2: Verified that S3 Bucket is set**

# %%
import boto3
import botocore
import os
import sagemaker


#bucket = sagemaker.Session().default_bucket()
prefix = "sagemaker/ipinsights-tutorial"
execution_role = sagemaker.get_execution_role()
region = boto3.Session().region_name

# check if the bucket exists
try:
    boto3.Session().client("s3").head_bucket(Bucket=bucket)
except botocore.exceptions.ParamValidationError as e:
    print(
        "Hey! You either forgot to specify your S3 bucket or you gave your bucket an invalid name!"
    )
except botocore.exceptions.ClientError as e:
    if e.response["Error"]["Code"] == "403":
        print(f"Hey! You don't have permission to access the bucket, {bucket}.")
    elif e.response["Error"]["Code"] == "404":
        print(f"Hey! Your bucket, {bucket}, doesn't exist!")
    else:
        raise
else:
    print(f"Training input/output will be stored in: s3://{bucket}/{prefix}")
# Out:
# Training input/output will be stored in: s3://aseansecaiml-25apr2023/sagemaker/ipinsights-tutorial

# %% [markdown]
# **Step 1.3: Next we download the modules necessary for synthetic data generation they do not exist.**
#
# > WARNING: If the Synethic data generation module do not exists, please get them from your instructor

# %%
from os import path

tools_bucket = f"jumpstart-cache-prod-{region}"  # Bucket containing the data generation module.
tools_prefix = "1p-algorithms-assets/ip-insights"  # Prefix for the data generation module

print(f"Tools Bucket set as: {tools_bucket}\n")
print(f"Tools Prefix set as: {tools_prefix}\n")

s3 = boto3.client("s3")

data_generation_file = "generate_data.py"  # Synthetic data generation module
script_parameters_file = "ip2asn-v4-u32.tsv.gz"

print(f" ### CHECKING IF DATA EXISTED ###")
if path.exists(data_generation_file) and path.exists(script_parameters_file):
    print(f"{data_generation_file} and {script_parameters_file} existed. You are good to go.")
else:
    print(f"WARNING: Please get the file from the instructer")

    
# if not path.exists(data_generation_file):
#     s3.download_file(tools_bucket, f"{tools_prefix}/{data_generation_file}", data_generation_file)
#     printf("downloading file")
# if not path.exists(script_parameters_file):
#     s3.download_file(
#         tools_bucket, f"{tools_prefix}/{script_parameters_file}", script_parameters_file
#     )
#     printf("downloading file")
# Out:
# Tools Bucket set as: jumpstart-cache-prod-ap-southeast-1
#
# Tools Prefix set as: 1p-algorithms-assets/ip-insights
#
#  ### CHECKING IF DATA EXISTED ###
# generate_data.py and ip2asn-v4-u32.tsv.gz existed. You are good to go.

# %% [markdown]
# ### 2. Dataset
#
# Apache Web Server ("httpd") is the most popular web server used on the internet. And luckily for us, it logs all requests processed by the server - by default. If a web page requires HTTP authentication, the Apache Web Server will log the IP address and authenticated user name for each requested resource.
#
# The [access logs](https://httpd.apache.org/docs/2.4/logs.html) are typically on the server under the file `/var/log/httpd/access_log`. From the example log output below, we see which IP addresses each user has connected with:
#
# ```
# 192.168.1.100 - user1 [15/Oct/2018:18:58:32 +0000] "GET /login_success?userId=1 HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36"
# 192.168.1.102 - user2 [15/Oct/2018:18:58:35 +0000] "GET /login_success?userId=2 HTTP/1.1" 200 - "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36"
# ...
# ```
#
# If we want to train an algorithm to detect suspicious activity, this dataset is ideal for SageMaker IP Insights.
#
# First, we determine the resource we want to be analyzing (such as a login page or access to a protected file). Then, we construct a dataset containing the history of all past user interactions with the resource. We extract out each 'access event' from the log and store the corresponding user name and IP address in a headerless CSV file with two columns. The first column will contain the user identifier string, and the second will contain the IPv4 address in decimal-dot notation.
#
# ```
# user1, 192.168.1.100
# user2, 193.168.1.102
# ...
# ```
#
# As a side note, the dataset should include all access events. That means some `<user_name, ip_address>` pairs will be repeated.
#
# #### Step 2.1: User Activity Simulation
# For this example, we are going to simulate our own web-traffic logs. We mock up a toy website example and simulate users logging into the website from mobile devices.
#
# The details of the simulation are explained in the script [here](./generate_data.py).

# %%
from generate_data import generate_dataset

# We simulate traffic for 10,000 users. This should yield about 3 million log lines (~700 MB).
NUM_USERS = 10000
log_file = "ipinsights_web_traffic.log"
generate_dataset(NUM_USERS, log_file)

# Visualize a few log lines
# !head $log_file
# Out:
# Loaded ASN List: 827696 ASNs.
# 158.64.253.21 - user_0 [09/Nov/2018:02:53:15 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 103.102.106.200 - user_0 [06/Nov/2018:08:00:53 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 103.102.34.221 - user_0 [05/Nov/2018:13:04:33 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 94.125.21.111 - user_0 [07/Nov/2018:07:03:18 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 94.125.50.187 - user_0 [13/Nov/2018:12:07:31 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 177.154.227.219 - user_0 [09/Nov/2018:14:57:06 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 94.125.9.63 - user_0 [04/Nov/2018:21:53:01 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 94.125.42.240 - user_0 [04/Nov/2018:01:56:41 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 94.124.238.181 - user_0 [10/Nov/2018:06:52:43 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"
# 94.125.57.238 - user_0 [04/Nov/2018:04:33:29 +0000] "GET /login_success HTTP/1.1" 200 476 "-" "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6) AppleWebKit/555.33 (KHTML, like Gecko) Chrome/1.1.1111.100 Safari/555.355"

# %% [markdown]
# ### 3. Prepare the dataset
# Now that we have our logs, we need to transform them into a format that IP Insights can use. As we mentioned above, we need to:
# 1. Choose the resource which we want to analyze users' history for
# 2. Extract our users' usage history of IP addresses
# 3. In addition, we want to separate our dataset into a training and test set. This will allow us to check for overfitting by evaluating our model on 'unseen' login events.
#
# For the rest of the notebook, we assume that the Apache Access Logs are in the Common Log Format as defined by the [Apache documentation](https://httpd.apache.org/docs/2.4/logs.html#accesslog). We start with reading the logs into a Pandas DataFrame for easy data exploration and pre-processing.

# %% [markdown]
# **Step 3.1: Reading the log file**

# %%
import pandas as pd

print(f"Reading csv. Please wait...")
df = pd.read_csv(
    log_file,
    sep=" ",
    na_values="-",
    header=None,
    names=[
        "ip_address",
        "rcf_id",
        "user",
        "timestamp",
        "time_zone",
        "request",
        "status",
        "size",
        "referer",
        "user_agent",
    ],
)
df.head()
# Out:
# Reading csv. Please wait...
#         ip_address  rcf_id    user              timestamp time_zone  \
# 0    158.64.253.21     NaN  user_0  [09/Nov/2018:02:53:15    +0000]
# 1  103.102.106.200     NaN  user_0  [06/Nov/2018:08:00:53    +0000]
# 2   103.102.34.221     NaN  user_0  [05/Nov/2018:13:04:33    +0000]
# 3    94.125.21.111     NaN  user_0  [07/Nov/2018:07:03:18    +0000]
# 4    94.125.50.187     NaN  user_0  [13/Nov/2018:12:07:31    +0000]
#
#                        request  status  size  referer  \
# 0  GET /login_success HTTP/1.1     200   476      NaN
# 1  GET /login_success HTTP/1.1     200   476      NaN
# 2  GET /login_success HTTP/1.1     200   476      NaN
# 3  GET /login_success HTTP/1.1     200   476      NaN
# 4  GET /login_success HTTP/1.1     200   476      NaN
#
#                                           user_agent
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 4  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...

# %% [markdown]
# **Step 3.2: We convert the log timestamp strings into Python datetimes so that we can sort and compare the data more easily.**

# %%
# Convert time stamps to DateTime objects
df["timestamp"] = pd.to_datetime(df["timestamp"], format="[%d/%b/%Y:%H:%M:%S")

# %%
# Compare the changed Timestamp with earlier
df.head()
# Out:
#         ip_address  rcf_id    user           timestamp time_zone  \
# 0    158.64.253.21     NaN  user_0 2018-11-09 02:53:15    +0000]
# 1  103.102.106.200     NaN  user_0 2018-11-06 08:00:53    +0000]
# 2   103.102.34.221     NaN  user_0 2018-11-05 13:04:33    +0000]
# 3    94.125.21.111     NaN  user_0 2018-11-07 07:03:18    +0000]
# 4    94.125.50.187     NaN  user_0 2018-11-13 12:07:31    +0000]
#
#                        request  status  size  referer  \
# 0  GET /login_success HTTP/1.1     200   476      NaN
# 1  GET /login_success HTTP/1.1     200   476      NaN
# 2  GET /login_success HTTP/1.1     200   476      NaN
# 3  GET /login_success HTTP/1.1     200   476      NaN
# 4  GET /login_success HTTP/1.1     200   476      NaN
#
#                                           user_agent
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 4  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...

# %%
# Total Unique Record
Total_Records = df.nunique()

print(f"Total Unique Record: {Total_Records}")
# Out:
# Total Unique Record: ip_address    2698371
# rcf_id              0
# user            10000
# timestamp      838194
# time_zone           1
# request             1
# status              1
# size                1
# referer             0
# user_agent          1
# dtype: int64

# %% [markdown]
# **Step 3.3: We also verify the time zones of all of the time stamps. If the log contains more than one time zone, we would need to standardize the timestamps.**

# %%
# Check if they are all in the same timezone
num_time_zones = len(df["time_zone"].unique())
num_time_zones

print(f"Num of Time Zone: {num_time_zones}")
# Out:
# Num of Time Zone: 1

# %% [markdown]
# As we see above, there is only one value in the entire `time_zone` column. Therefore, all of the timestamps are in the same time zone, and we do not need to standardize them. We can skip the next cell and go to [1. Selecting a Resource](#1.-Select-Resource).
#
# If there is more than one time_zone in your dataset, then we parse the timezone offset and update the corresponding datetime object.
#
# **Note:** The next cell takes about 5-10 minutes to run.

# %%
from datetime import datetime
import pytz


def apply_timezone(row):
    tz = row[1]
    tz_offset = int(tz[:3]) * 60  # Hour offset
    tz_offset += int(tz[3:5])  # Minutes offset
    return row[0].replace(tzinfo=pytz.FixedOffset(tz_offset))


if num_time_zones > 1:
    print("f We will standardize the timezone since there are more than 1 timezone.")
    df["timestamp"] = df[["timestamp", "time_zone"]].apply(apply_timezone, axis=1)

# %% [markdown]
# ### 4. Analyze Dataset

# %% [markdown]
# #### 4.1. Select Resource
# Our goal is to train an IP Insights algorithm to analyze the history of user logins such that we can predict how suspicious a login event is.
#
# In our simulated web server, the server logs a `GET` request to the `/login_success` page everytime a user successfully logs in. We filter our Apache logs for `GET` requests for `/login_success`. We also filter for requests that have a `status_code == 200`, to ensure that the page request was well formed.
#
# **Note:** every web server handles logins differently. For your dataset, determine which resource you will need to be analyzing to correctly frame this problem. Depending on your usecase, you may need to do more data exploration and preprocessing.

# %%
df = df[(df["request"].str.startswith("GET /login_success")) & (df["status"] == 200)]

# %%
df.head()
# Out:
#         ip_address  rcf_id    user           timestamp time_zone  \
# 0    158.64.253.21     NaN  user_0 2018-11-09 02:53:15    +0000]
# 1  103.102.106.200     NaN  user_0 2018-11-06 08:00:53    +0000]
# 2   103.102.34.221     NaN  user_0 2018-11-05 13:04:33    +0000]
# 3    94.125.21.111     NaN  user_0 2018-11-07 07:03:18    +0000]
# 4    94.125.50.187     NaN  user_0 2018-11-13 12:07:31    +0000]
#
#                        request  status  size  referer  \
# 0  GET /login_success HTTP/1.1     200   476      NaN
# 1  GET /login_success HTTP/1.1     200   476      NaN
# 2  GET /login_success HTTP/1.1     200   476      NaN
# 3  GET /login_success HTTP/1.1     200   476      NaN
# 4  GET /login_success HTTP/1.1     200   476      NaN
#
#                                           user_agent
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...
# 4  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...

# %% [markdown]
# #### 4.2. Extract Users and IP address
# Now that our DataFrame only includes log events for the resource we want to analyze, we extract the relevant fields to construct a IP Insights dataset.
#
# IP Insights takes in a headerless CSV file with two columns: an entity (username) ID string and the IPv4 address in decimal-dot notation. Fortunately, the Apache Web Server Access Logs output IP addresses and authenticated usernames in their own columns.
#
# **Note:** Each website handles user authentication differently. If the Access Log does not output an authenticated user, you could explore the website's query strings or work with your website developers on another solution.

# %%
df = df[["user", "ip_address", "timestamp"]]
df.head()
# Out:
#      user       ip_address           timestamp
# 0  user_0    158.64.253.21 2018-11-09 02:53:15
# 1  user_0  103.102.106.200 2018-11-06 08:00:53
# 2  user_0   103.102.34.221 2018-11-05 13:04:33
# 3  user_0    94.125.21.111 2018-11-07 07:03:18
# 4  user_0    94.125.50.187 2018-11-13 12:07:31

# %% [markdown]
# #### 4.3. Create training and test dataset
# As part of training a model, we want to evaluate how it generalizes to data it has never seen before.
#
# Typically, you create a test set by reserving a random percentage of your dataset and evaluating the model after training. However, for machine learning models that make future predictions on historical data, we want to use out-of-time testing. Instead of randomly sampling our dataset, we split our dataset into two contiguous time windows. The first window is the training set, and the second is the test set.
#
# We first look at the time range of our dataset to select a date to use as the partition between the training and test set.

# %%
df["timestamp"].describe()
# Out:
# /tmp/ipykernel_10826/52595715.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df["timestamp"].describe()
# count                 3024129
# unique                 838194
# top       2018-11-13 23:23:10
# freq                       16
# first     2018-11-04 00:00:01
# last      2018-11-14 00:00:00
# Name: timestamp, dtype: object

# %% [markdown]
# We have login events for 10 days. Let's take the first week (7 days) of data as training and then use the last 3 days for the test set.

# %%
time_partition = (
    datetime(2018, 11, 11, tzinfo=pytz.FixedOffset(0))
    if num_time_zones > 1
    else datetime(2018, 11, 11)
)

train_df = df[df["timestamp"] <= time_partition]
test_df = df[df["timestamp"] > time_partition]

# %% [markdown]
# Checkout the timestamp of training data and test data. The timestamp of training data should be **before** 2018-11-11 and test data should be **after** 2018-11-11

# %%
#Compare Training and Test Data
print(f"Training Data")
train_df.head()
# Out:
# Training Data
#      user       ip_address           timestamp
# 0  user_0    158.64.253.21 2018-11-09 02:53:15
# 1  user_0  103.102.106.200 2018-11-06 08:00:53
# 2  user_0   103.102.34.221 2018-11-05 13:04:33
# 3  user_0    94.125.21.111 2018-11-07 07:03:18
# 5  user_0  177.154.227.219 2018-11-09 14:57:06

# %%
print(f"Test Data")
test_df.head()
# Out:
# Test Data
#       user      ip_address           timestamp
# 4   user_0   94.125.50.187 2018-11-13 12:07:31
# 14  user_0  103.102.91.142 2018-11-13 08:00:12
# 16  user_0   103.102.43.72 2018-11-13 16:11:54
# 21  user_0  103.102.86.206 2018-11-13 06:15:07
# 22  user_0    94.125.80.36 2018-11-12 13:21:56

# %% [markdown]
# Now that we have our training dataset, we shuffle it.
#
# Shuffling improves the model's performance since SageMaker IP Insights uses stochastic gradient descent. This ensures that login events for the same user are less likely to occur in the same mini batch. This allows the model to improve its performance in between predictions of the same user, which will improve training convergence.

# %%
# Shuffle train data
train_df = train_df.sample(frac=1)
train_df.head()
# Out:
#               user       ip_address           timestamp
# 61125     user_259  157.119.235.190 2018-11-06 04:58:05
# 1107985  user_3886    76.72.107.195 2018-11-08 16:48:46
# 2778339  user_9121    209.115.50.12 2018-11-08 03:20:20
# 1808248  user_5867    195.58.235.84 2018-11-10 10:54:36
# 1500486  user_5176    89.161.26.173 2018-11-10 02:22:50

# %% [markdown]
# ### 5. Store Data on S3

# %% [markdown]
# Now that we have simulated (or scraped) our datasets, we have to prepare and upload it to S3.
#
# We will be doing local inference, therefore we don't need to upload our test dataset.

# %%
# Output dataset as headerless CSV
train_data = train_df.to_csv(index=False, header=False, columns=["user", "ip_address"])

# %%
# Upload data to S3 key
train_data_file = "train.csv"
key = os.path.join(prefix, "train", train_data_file)
s3_train_data = f"s3://{bucket}/{key}"

print(f"Uploading data to: {s3_train_data}")
boto3.resource("s3").Bucket(bucket).Object(key).put(Body=train_data)

# Configure SageMaker IP Insights Input Channels
input_data = {
    "train": sagemaker.session.s3_input(
        s3_train_data, distribution="FullyReplicated", content_type="text/csv"
    )
}
# Out:
# Uploading data to: s3://aseansecaiml-25apr2023/sagemaker/ipinsights-tutorial/train/train.csv
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
#List all the files in S3
s3 = boto3.resource('s3')
my_bucket = s3.Bucket(bucket)

for my_bucket_object in my_bucket.objects.all():
    print(f"{my_bucket_object.key}\n")
# Out:
# sagemaker/ipinsights-tutorial/train/train.csv

# %% [markdown]
# ## Training
# ---
# Once the data is preprocessed and available in the necessary format, the next step is to train our model on the data. There are number of parameters required by the SageMaker IP Insights algorithm to configure the model and define the computational environment in which training will take place. The first of these is to point to a container image which holds the algorithms training and hosting code:

# %% [markdown]
# ### 1. Getting Prebuild SageMaker Docker Image

# %%
# This is deprecated to sagemaker.image_uris.retrieve
from sagemaker.amazon.amazon_estimator import image_uris

image = image_uris.retrieve(framework='ipinsights',region=boto3.Session().region_name)

# %% [markdown]
# Then, we need to determine the training cluster to use. The IP Insights algorithm supports both CPU and GPU training. We recommend using GPU machines as they will train faster. However, when the size of your dataset increases, it can become more economical to use multiple CPU machines running with distributed training. See [Recommended Instance Types](https://docs.aws.amazon.com/sagemaker/latest/dg/ip-insights.html#ip-insights-instances) for more details.
#
# ### 2. Training
# #### 2.1 Training Job Configuration
# - **train_instance_type**: the instance type to train on. We recommend `p3.2xlarge` for single GPU, `p3.8xlarge` for multi-GPU, and `m5.2xlarge` if using distributed training with CPU;
# - **train_instance_count**: the number of worker nodes in the training cluster.
#
# We need to also configure SageMaker IP Insights-specific hypeparameters:
#
# #### 2.2 Model Hyperparameters
# - **num_entity_vectors**: the total number of embeddings to train. We use an internal hashing mechanism to map the entity ID strings to an embedding index; therefore, using an embedding size larger than the total number of possible values helps reduce the number of hash collisions. We recommend this value to be 2x the total number of unique entites (i.e. user names) in your dataset;
# - **vector_dim**: the size of the entity and IP embedding vectors. The larger the value, the more information can be encoded using these representations but using too large vector representations may cause the model to overfit, especially for small training data sets;
# - **num_ip_encoder_layers**: the number of layers in the IP encoder network. The larger the number of layers, the higher the model capacity to capture patterns among IP addresses. However, large number of layers increases the chance of overfitting. `num_ip_encoder_layers=1` is a good value to start experimenting with;
# - **random_negative_sampling_rate**: the number of randomly generated negative samples to produce per 1 positive sample; `random_negative_sampling_rate=1` is a good value to start experimenting with;
#     - Random negative samples are produced by drawing each octet from a uniform distributed of [0, 255];
# - **shuffled_negative_sampling_rate**: the number of shuffled negative samples to produce per 1 positive sample; `shuffled_negative_sampling_rate=1` is a good value to start experimenting with;
#     - Shuffled negative samples are produced by shuffling the accounts within a batch;
#
# #### 2.3 Training Hyperparameters
# - **epochs**: the number of epochs to train. Increase this value if you continue to see the accuracy and cross entropy improving over the last few epochs;
# - **mini_batch_size**: how many examples in each mini_batch. A smaller number improves convergence with stochastic gradient descent. But a larger number is necessary if using shuffled_negative_sampling to avoid sampling a wrong account for a negative sample;
# - **learning_rate**: the learning rate for the Adam optimizer (try ranges in [0.001, 0.1]). Too large learning rate may cause the model to diverge since the training would be likely to overshoot minima. On the other hand, too small learning rate slows down the convergence;
# - **weight_decay**: L2 regularization coefficient. Regularization is required to prevent the model from overfitting the training data. Too large of a value will prevent the model from learning anything;
#
# For more details, see [Amazon SageMaker IP Insights (Hyperparameters)](https://docs.aws.amazon.com/sagemaker/latest/dg/ip-insights-hyperparameters.html). Additionally, most of these hyperparameters can be found using SageMaker Automatic Model Tuning; see [Amazon SageMaker IP Insights (Model Tuning)](https://docs.aws.amazon.com/sagemaker/latest/dg/ip-insights-tuning.html) for more details.

# %%
# Set up the estimator with training job configuration
ip_insights = sagemaker.estimator.Estimator(
    image,
    execution_role,
    instance_count=1,
    instance_type="ml.p3.2xlarge",
    output_path=f"s3://{bucket}/{prefix}/output",
    sagemaker_session=sagemaker.Session(),
)

# Configure algorithm-specific hyperparameters
ip_insights.set_hyperparameters(
    num_entity_vectors="20000",
    random_negative_sampling_rate="5",
    vector_dim="128",
    mini_batch_size="1000",
    epochs="5",
    learning_rate="0.01",
)

# Start the training job (should take about ~1.5 minute / epoch to complete)
ip_insights.fit(input_data)
# Out:
# INFO:sagemaker:Creating training-job with name: ipinsights-2023-05-03-09-47-14-417
# 2023-05-03 09:47:14 Starting - Starting the training job...
# 2023-05-03 09:47:37 Starting - Preparing the instances for training......
# 2023-05-03 09:48:28 Downloading - Downloading input data...
# 2023-05-03 09:48:48 Training - Downloading the training image............
# 2023-05-03 09:50:54 Training - Training image download completed. Training in progress...Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Wed May  3 09:51:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   32C    P0    24W / 300W |      0MiB / 16384MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 525.85.12.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# [05/03/2023 09:51:25 INFO 140247015941952] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'batch_metrics_publish_interval': '1000', 'epochs': '10', 'learning_rate': '0.001', 'mini_batch_size': '5000', 'num_entity_vectors': '100000', 'num_ip_encoder_layers': '1', 'random_negative_sampling_rate': '1', 'shuffled_negative_sampling_rate': '1', 'vector_dim': '128', 'weight_decay': '0.00001', '_kvstore': 'auto_gpu', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_tuning_objective_metric': ''}
# [05/03/2023 09:51:25 INFO 140247015941952] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'epochs': '5', 'learning_rate': '0.01', 'mini_batch_size': '1000', 'num_entity_vectors': '20000', 'random_negative_sampling_rate': '5', 'vector_dim': '128'}
# [05/03/2023 09:51:25 INFO 140247015941952] Final configuration: {'batch_metrics_publish_interval': '1000', 'epochs': '5', 'learning_rate': '0.01', 'mini_batch_size': '1000', 'num_entity_vectors': '20000', 'num_ip_encoder_layers': '1', 'random_negative_sampling_rate': '5', 'shuffled_negative_sampling_rate': '1', 'vector_dim': '128', 'weight_decay': '0.00001', '_kvstore': 'auto_gpu', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_tuning_objective_metric': ''}
# [05/03/2023 09:51:25 WARNING 140247015941952] Loggers have already been setup.
# [05/03/2023 09:51:25 INFO 140247015941952] nvidia-smi: took 0.031 seconds to run.
# [05/03/2023 09:51:25 INFO 140247015941952] nvidia-smi identified 1 GPUs.
# Process 7 is a worker.
# [05/03/2023 09:51:25 INFO 140247015941952] Using default worker.
# [05/03/2023 09:51:25 INFO 140247015941952] Loaded iterator creator application/x-ndarray for content type ('application/x-ndarray', '1.0')
# [05/03/2023 09:51:25 INFO 140247015941952] Loaded iterator creator text/csv for content type ('text/csv', '1.0')
# [05/03/2023 09:51:25 INFO 140247015941952] Checkpoint loading and saving are disabled.
# [05/03/2023 09:51:25 INFO 140247015941952] Number of GPUs being used: 1
# #metrics {"StartTime": 1683107485.219632, "EndTime": 1683107485.2453077, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 25.470972061157227, "count": 1, "min": 25.470972061157227, "max": 25.470972061157227}}}
# #metrics {"StartTime": 1683107485.2454543, "EndTime": 1683107485.24549, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/03/2023 09:51:25 INFO 140247015941952] Create Store: device
# [09:51:27] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_Cuda_11.1.x.192.0/AL2_x86_64/generic-flavor/src/src/kvstore/./kvstore_local.h:306: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use kv.row_sparse_pull() or module.prepare() with row_ids.
# [09:51:27] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.3.x_Cuda_11.1.x.192.0/AL2_x86_64/generic-flavor/src/src/operator/././../common/utils.h:450: Optimizer with lazy_update = True detected. Be aware that lazy update with row_sparse gradient is different from standard update, and may lead to different empirical results. See https://mxnet.incubator.apache.org/api/python/optimization/optimization.html for more details.
# [05/03/2023 09:51:27 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.488
# [05/03/2023 09:51:27 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.6931819458007813
# [05/03/2023 09:51:33 INFO 140247015941952] Epoch[0] Batch [1000]#011Speed: 161074.44 samples/sec#011binary_classification_accuracy=0.926890#011binary_classification_cross_entropy=0.199784
# [05/03/2023 09:51:33 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=1000 train binary_classification_accuracy <score>=0.9268901098901099
# [05/03/2023 09:51:33 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=1000 train binary_classification_cross_entropy <loss>=0.1997836946226381
# [05/03/2023 09:51:39 INFO 140247015941952] Epoch[0] Batch [2000]#011Speed: 166394.20 samples/sec#011binary_classification_accuracy=0.949261#011binary_classification_cross_entropy=0.149758
# [05/03/2023 09:51:39 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=2000 train binary_classification_accuracy <score>=0.9492608695652174
# [05/03/2023 09:51:39 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=2000 train binary_classification_cross_entropy <loss>=0.14975789375247983
# [05/03/2023 09:51:45 INFO 140247015941952] Epoch[0] Batch [3000]#011Speed: 166387.05 samples/sec#011binary_classification_accuracy=0.958967#011binary_classification_cross_entropy=0.126870
# [05/03/2023 09:51:45 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=3000 train binary_classification_accuracy <score>=0.9589670109963345
# [05/03/2023 09:51:45 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=3000 train binary_classification_cross_entropy <loss>=0.12687029838244226
# [05/03/2023 09:51:52 INFO 140247015941952] Epoch[0] Batch [4000]#011Speed: 165042.68 samples/sec#011binary_classification_accuracy=0.964457#011binary_classification_cross_entropy=0.113878
# [05/03/2023 09:51:52 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=4000 train binary_classification_accuracy <score>=0.9644573856535866
# [05/03/2023 09:51:52 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=4000 train binary_classification_cross_entropy <loss>=0.11387776749374211
# [05/03/2023 09:51:58 INFO 140247015941952] Epoch[0] Batch [5000]#011Speed: 165468.34 samples/sec#011binary_classification_accuracy=0.968040#011binary_classification_cross_entropy=0.105209
# [05/03/2023 09:51:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=5000 train binary_classification_accuracy <score>=0.9680403919216157
# [05/03/2023 09:51:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=5000 train binary_classification_cross_entropy <loss>=0.10520922643626793
# [05/03/2023 09:52:04 INFO 140247015941952] Epoch[0] Batch [6000]#011Speed: 161891.67 samples/sec#011binary_classification_accuracy=0.970585#011binary_classification_cross_entropy=0.099085
# [05/03/2023 09:52:04 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=6000 train binary_classification_accuracy <score>=0.9705849025162473
# [05/03/2023 09:52:04 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=6000 train binary_classification_cross_entropy <loss>=0.09908482173696555
# [05/03/2023 09:52:10 INFO 140247015941952] Epoch[0] Batch [7000]#011Speed: 149316.14 samples/sec#011binary_classification_accuracy=0.972472#011binary_classification_cross_entropy=0.094543
# [05/03/2023 09:52:10 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=7000 train binary_classification_accuracy <score>=0.9724720754177975
# [05/03/2023 09:52:10 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=7000 train binary_classification_cross_entropy <loss>=0.09454333185076867
# [05/03/2023 09:52:17 INFO 140247015941952] Epoch[0] Batch [8000]#011Speed: 164227.74 samples/sec#011binary_classification_accuracy=0.973933#011binary_classification_cross_entropy=0.090968
# [05/03/2023 09:52:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=8000 train binary_classification_accuracy <score>=0.9739333833270841
# [05/03/2023 09:52:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=8000 train binary_classification_cross_entropy <loss>=0.0909680759647819
# [05/03/2023 09:52:23 INFO 140247015941952] Epoch[0] Batch [9000]#011Speed: 165385.98 samples/sec#011binary_classification_accuracy=0.975137#011binary_classification_cross_entropy=0.088069
# [05/03/2023 09:52:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=9000 train binary_classification_accuracy <score>=0.9751374291745362
# [05/03/2023 09:52:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=9000 train binary_classification_cross_entropy <loss>=0.08806870291686272
# [05/03/2023 09:52:29 INFO 140247015941952] Epoch[0] Batch [10000]#011Speed: 163732.49 samples/sec#011binary_classification_accuracy=0.976114#011binary_classification_cross_entropy=0.085624
# [05/03/2023 09:52:29 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=10000 train binary_classification_accuracy <score>=0.9761137886211378
# [05/03/2023 09:52:29 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=10000 train binary_classification_cross_entropy <loss>=0.08562385382574567
# [05/03/2023 09:52:35 INFO 140247015941952] Epoch[0] Batch [11000]#011Speed: 159261.05 samples/sec#011binary_classification_accuracy=0.976931#011binary_classification_cross_entropy=0.083635
# [05/03/2023 09:52:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=11000 train binary_classification_accuracy <score>=0.9769305517680211
# [05/03/2023 09:52:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=11000 train binary_classification_cross_entropy <loss>=0.08363477865794217
# [05/03/2023 09:52:41 INFO 140247015941952] Epoch[0] Batch [12000]#011Speed: 160084.24 samples/sec#011binary_classification_accuracy=0.977608#011binary_classification_cross_entropy=0.081983
# [05/03/2023 09:52:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=12000 train binary_classification_accuracy <score>=0.9776081993167236
# [05/03/2023 09:52:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=12000 train binary_classification_cross_entropy <loss>=0.08198329083862509
# [05/03/2023 09:52:47 INFO 140247015941952] Epoch[0] Batch [13000]#011Speed: 165744.31 samples/sec#011binary_classification_accuracy=0.978229#011binary_classification_cross_entropy=0.080436
# [05/03/2023 09:52:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=13000 train binary_classification_accuracy <score>=0.9782289054688101
# [05/03/2023 09:52:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=13000 train binary_classification_cross_entropy <loss>=0.0804364712109759
# [05/03/2023 09:52:53 INFO 140247015941952] Epoch[0] Batch [14000]#011Speed: 165265.63 samples/sec#011binary_classification_accuracy=0.978758#011binary_classification_cross_entropy=0.079169
# [05/03/2023 09:52:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=14000 train binary_classification_accuracy <score>=0.978757660167131
# [05/03/2023 09:52:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, batch=14000 train binary_classification_cross_entropy <loss>=0.07916850060642161
# [05/03/2023 09:52:58 INFO 140247015941952] Epoch[0] Train-binary_classification_accuracy=0.979147
# [05/03/2023 09:52:58 INFO 140247015941952] Epoch[0] Train-binary_classification_cross_entropy=0.078176
# [05/03/2023 09:52:58 INFO 140247015941952] Epoch[0] Time cost=91.052
# [05/03/2023 09:52:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.9791469059990553
# [05/03/2023 09:52:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.07817583764781111
# #metrics {"StartTime": 1683107485.245399, "EndTime": 1683107578.730253, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "update.time": {"sum": 93484.5187664032, "count": 1, "min": 93484.5187664032, "max": 93484.5187664032}}}
# [05/03/2023 09:52:58 INFO 140247015941952] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1683107485.2457037, "EndTime": 1683107578.7305615, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 14813834.0, "count": 1, "min": 14813834, "max": 14813834}, "Total Batches Seen": {"sum": 14819.0, "count": 1, "min": 14819, "max": 14819}, "Max Records Seen Between Resets": {"sum": 14813834.0, "count": 1, "min": 14813834, "max": 14813834}, "Max Batches Seen Between Resets": {"sum": 14819.0, "count": 1, "min": 14819, "max": 14819}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/03/2023 09:52:58 INFO 140247015941952] #throughput_metric: host=algo-1, train throughput=158462.1766666907 records/second
# [05/03/2023 09:52:58 WARNING 140247015941952] Already bound, ignoring bind()
# /opt/amazon/lib/python3.7/site-packages/mxnet/module/base_module.py:502: UserWarning: Parameters already initialized and force_init=False. init_params call ignored.
#   allow_missing=allow_missing, force_init=force_init)
# [05/03/2023 09:52:58 WARNING 140247015941952] optimizer already initialized, ignoring...
# [05/03/2023 09:52:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.985
# [05/03/2023 09:52:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_cross_entropy <loss>=0.052093795776367184
# [05/03/2023 09:53:04 INFO 140247015941952] Epoch[1] Batch [1000]#011Speed: 160927.57 samples/sec#011binary_classification_accuracy=0.986090#011binary_classification_cross_entropy=0.059693
# [05/03/2023 09:53:04 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=1000 train binary_classification_accuracy <score>=0.9860899100899101
# [05/03/2023 09:53:04 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=1000 train binary_classification_cross_entropy <loss>=0.05969271771891134
# [05/03/2023 09:53:11 INFO 140247015941952] Epoch[1] Batch [2000]#011Speed: 165039.69 samples/sec#011binary_classification_accuracy=0.985878#011binary_classification_cross_entropy=0.059910
# [05/03/2023 09:53:11 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=2000 train binary_classification_accuracy <score>=0.9858775612193903
# [05/03/2023 09:53:11 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=2000 train binary_classification_cross_entropy <loss>=0.059910105974539586
# [05/03/2023 09:53:17 INFO 140247015941952] Epoch[1] Batch [3000]#011Speed: 165261.93 samples/sec#011binary_classification_accuracy=0.985917#011binary_classification_cross_entropy=0.059501
# [05/03/2023 09:53:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=3000 train binary_classification_accuracy <score>=0.9859170276574475
# [05/03/2023 09:53:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=3000 train binary_classification_cross_entropy <loss>=0.05950119164799579
# [05/03/2023 09:53:23 INFO 140247015941952] Epoch[1] Batch [4000]#011Speed: 165949.31 samples/sec#011binary_classification_accuracy=0.985917#011binary_classification_cross_entropy=0.059457
# [05/03/2023 09:53:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=4000 train binary_classification_accuracy <score>=0.9859172706823294
# [05/03/2023 09:53:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=4000 train binary_classification_cross_entropy <loss>=0.05945742442076935
# [05/03/2023 09:53:29 INFO 140247015941952] Epoch[1] Batch [5000]#011Speed: 163993.78 samples/sec#011binary_classification_accuracy=0.985975#011binary_classification_cross_entropy=0.059230
# [05/03/2023 09:53:29 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=5000 train binary_classification_accuracy <score>=0.9859746050789842
# [05/03/2023 09:53:29 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=5000 train binary_classification_cross_entropy <loss>=0.05922992014718089
# [05/03/2023 09:53:35 INFO 140247015941952] Epoch[1] Batch [6000]#011Speed: 165602.02 samples/sec#011binary_classification_accuracy=0.985993#011binary_classification_cross_entropy=0.059199
# [05/03/2023 09:53:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=6000 train binary_classification_accuracy <score>=0.9859928345275787
# [05/03/2023 09:53:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=6000 train binary_classification_cross_entropy <loss>=0.05919880543413052
# [05/03/2023 09:53:41 INFO 140247015941952] Epoch[1] Batch [7000]#011Speed: 164232.05 samples/sec#011binary_classification_accuracy=0.985974#011binary_classification_cross_entropy=0.059246
# [05/03/2023 09:53:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=7000 train binary_classification_accuracy <score>=0.9859742893872304
# [05/03/2023 09:53:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch=7000 train binary_classification_cross_entropy <loss>=0.0592456579629293
# [05/03/2023 09:53:47 INFO 140247015941952] Epoch[1] Batch [8000]#011Speed: 167254.44 samples/sec#011binary_classification_accuracy=0.986012#011binary_classification_cross_entropy=0.059115
# [05/03/2023 09:53:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=1, batch
#progress_metric: host=algo-1, completed 40.0 % of epochs
# #metrics {"StartTime": 1683107578.7308683, "EndTime": 1683107668.8066738, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 29627668.0, "count": 1, "min": 29627668, "max": 29627668}, "Total Batches Seen": {"sum": 29638.0, "count": 1, "min": 29638, "max": 29638}, "Max Records Seen Between Resets": {"sum": 14813834.0, "count": 1, "min": 14813834, "max": 14813834}, "Max Batches Seen Between Resets": {"sum": 14819.0, "count": 1, "min": 14819, "max": 14819}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/03/2023 09:54:28 INFO 140247015941952] #throughput_metric: host=algo-1, train throughput=164459.34243041006 records/second
# [05/03/2023 09:54:28 WARNING 140247015941952] Already bound, ignoring bind()
# [05/03/2023 09:54:28 WARNING 140247015941952] optimizer already initialized, ignoring...
# [05/03/2023 09:54:28 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_accuracy <score>=0.982
# [05/03/2023 09:54:28 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=0 train binary_classification_cross_entropy <loss>=0.07425054931640625
# [05/03/2023 09:54:34 INFO 140247015941952] Epoch[2] Batch [1000]#011Speed: 165349.89 samples/sec#011binary_classification_accuracy=0.986831#011binary_classification_cross_entropy=0.056033
# [05/03/2023 09:54:34 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=1000 train binary_classification_accuracy <score>=0.9868311688311688
# [05/03/2023 09:54:34 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=1000 train binary_classification_cross_entropy <loss>=0.05603301972799844
# [05/03/2023 09:54:40 INFO 140247015941952] Epoch[2] Batch [2000]#011Speed: 165137.59 samples/sec#011binary_classification_accuracy=0.986634#011binary_classification_cross_entropy=0.056532
# [05/03/2023 09:54:40 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=2000 train binary_classification_accuracy <score>=0.9866341829085458
# [05/03/2023 09:54:40 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=2000 train binary_classification_cross_entropy <loss>=0.05653152103128581
# [05/03/2023 09:54:47 INFO 140247015941952] Epoch[2] Batch [3000]#011Speed: 163305.62 samples/sec#011binary_classification_accuracy=0.986657#011binary_classification_cross_entropy=0.056472
# [05/03/2023 09:54:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=3000 train binary_classification_accuracy <score>=0.9866574475174942
# [05/03/2023 09:54:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=3000 train binary_classification_cross_entropy <loss>=0.056472008760751626
# [05/03/2023 09:54:53 INFO 140247015941952] Epoch[2] Batch [4000]#011Speed: 166074.93 samples/sec#011binary_classification_accuracy=0.986575#011binary_classification_cross_entropy=0.056633
# [05/03/2023 09:54:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=4000 train binary_classification_accuracy <score>=0.9865753561609598
# [05/03/2023 09:54:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=4000 train binary_classification_cross_entropy <loss>=0.05663330441765474
# [05/03/2023 09:54:59 INFO 140247015941952] Epoch[2] Batch [5000]#011Speed: 163859.48 samples/sec#011binary_classification_accuracy=0.986543#011binary_classification_cross_entropy=0.056612
# [05/03/2023 09:54:59 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=5000 train binary_classification_accuracy <score>=0.9865430913817237
# [05/03/2023 09:54:59 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=5000 train binary_classification_cross_entropy <loss>=0.05661210523512668
# [05/03/2023 09:55:05 INFO 140247015941952] Epoch[2] Batch [6000]#011Speed: 161565.36 samples/sec#011binary_classification_accuracy=0.986522#011binary_classification_cross_entropy=0.056672
# [05/03/2023 09:55:05 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch=6000 train binary_classification_accuracy <score>=0.9865215797367105
# [05/03/2023 09:55:05 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, batch
58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, train binary_classification_accuracy <score>=0.9866002429313719
# [05/03/2023 09:55:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=2, train binary_classification_cross_entropy <loss>=0.05638149914685849
# #metrics {"StartTime": 1683107668.8064768, "EndTime": 1683107758.7089698, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 89901.96514129639, "count": 1, "min": 89901.96514129639, "max": 89901.96514129639}}}
# [05/03/2023 09:55:58 INFO 140247015941952] #progress_metric: host=algo-1, completed 60.0 % of epochs
# #metrics {"StartTime": 1683107668.8069696, "EndTime": 1683107758.7092185, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 44441502.0, "count": 1, "min": 44441502, "max": 44441502}, "Total Batches Seen": {"sum": 44457.0, "count": 1, "min": 44457, "max": 44457}, "Max Records Seen Between Resets": {"sum": 14813834.0, "count": 1, "min": 14813834, "max": 14813834}, "Max Batches Seen Between Resets": {"sum": 14819.0, "count": 1, "min": 14819, "max": 14819}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/03/2023 09:55:58 INFO 140247015941952] #throughput_metric: host=algo-1, train throughput=164776.92245914976 records/second
# [05/03/2023 09:55:58 WARNING 140247015941952] Already bound, ignoring bind()
# [05/03/2023 09:55:58 WARNING 140247015941952] optimizer already initialized, ignoring...
# [05/03/2023 09:55:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_accuracy <score>=0.983
# [05/03/2023 09:55:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=0 train binary_classification_cross_entropy <loss>=0.05726934814453125
# [05/03/2023 09:56:04 INFO 140247015941952] Epoch[3] Batch [1000]#011Speed: 161581.40 samples/sec#011binary_classification_accuracy=0.987077#011binary_classification_cross_entropy=0.054778
# [05/03/2023 09:56:04 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=1000 train binary_classification_accuracy <score>=0.9870769230769231
# [05/03/2023 09:56:04 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=1000 train binary_classification_cross_entropy <loss>=0.05477814186583985
# [05/03/2023 09:56:10 INFO 140247015941952] Epoch[3] Batch [2000]#011Speed: 164828.13 samples/sec#011binary_classification_accuracy=0.986862#011binary_classification_cross_entropy=0.055341
# [05/03/2023 09:56:10 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=2000 train binary_classification_accuracy <score>=0.9868620689655172
# [05/03/2023 09:56:10 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=2000 train binary_classification_cross_entropy <loss>=0.05534148540906701
# [05/03/2023 09:56:17 INFO 140247015941952] Epoch[3] Batch [3000]#011Speed: 166017.78 samples/sec#011binary_classification_accuracy=0.986820#011binary_classification_cross_entropy=0.055351
# [05/03/2023 09:56:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=3000 train binary_classification_accuracy <score>=0.9868203932022659
# [05/03/2023 09:56:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=3000 train binary_classification_cross_entropy <loss>=0.055350741457279744
# [05/03/2023 09:56:23 INFO 140247015941952] Epoch[3] Batch [4000]#011Speed: 164806.68 samples/sec#011binary_classification_accuracy=0.986770#011binary_classification_cross_entropy=0.055459
# [05/03/2023 09:56:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=4000 train binary_classification_accuracy <score>=0.9867695576105974
# [05/03/2023 09:56:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=4000 train binary_classification_cross_entropy <loss>=0.05545939083714332
# [05/03/2023 09:56:29 INFO 140247015941952] Epoch[3] Batch [5000]#011Speed: 165065.53 samples/sec#011binary_classification_accuracy=0.986757#011binary_classification_cross_entropy=0.055365
# [05/03/2023 09:56:29 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=5000 train binary_classification_accuracy <score>=0.9867570485902819
# [05/03/2023 09:56:29 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=5000 train binary_classification_cross_entropy <loss>=0.05536520195922669
# [05/03/2023 09:56:35 INFO 140247015941952] Epoch[3] Batch [6000]#011Speed: 164604.72 samples/sec#011binary_classification_accuracy=0.986748#011binary_classification_cross_entropy=0.055374
# [05/03/2023 09:56:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=6000 train binary_classification_accuracy <score>=0.9867478753541077
# [05/03/2023 09:56:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=6000 train binary_classification_cross_entropy <loss>=0.0553735190939653
# [05/03/2023 09:56:41 INFO 140247015941952] Epoch[3] Batch [7000]#011Speed: 164660.81 samples/sec#011binary_classification_accuracy=0.986728#011binary_classification_cross_entropy=0.055472
# [05/03/2023 09:56:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=7000 train binary_classification_accuracy <score>=0.9867276103413798
# [05/03/2023 09:56:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=7000 train binary_classification_cross_entropy <loss>=0.05547163341202373
# [05/03/2023 09:56:47 INFO 140247015941952] Epoch[3] Batch [8000]#011Speed: 165695.15 samples/sec#011binary_classification_accuracy=0.986726#011binary_classification_cross_entropy=0.055440
# [05/03/2023 09:56:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=8000 train binary_classification_accuracy <score>=0.9867256592925884
# [05/03/2023 09:56:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=8000 train binary_classification_cross_entropy <loss>=0.05543987284420639
# [05/03/2023 09:56:53 INFO 140247015941952] Epoch[3] Batch [9000]#011Speed: 164863.08 samples/sec#011binary_classification_accuracy=0.986749#011binary_classification_cross_entropy=0.055395
# [05/03/2023 09:56:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=9000 train binary_classification_accuracy <score>=0.9867493611820909
# [05/03/2023 09:56:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=9000 train binary_classification_cross_entropy <loss>=0.05539456096403785
# [05/03/2023 09:56:59 INFO 140247015941952] Epoch[3] Batch [10000]#011Speed: 164437.25 samples/sec#011binary_classification_accuracy=0.986772#011binary_classification_cross_entropy=0.055321
# [05/03/2023 09:56:59 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=10000 train binary_classification_accuracy <score>=0.9867718228177182
# [05/03/2023 09:56:59 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=10000 train binary_classification_cross_entropy <loss>=0.05532092967518281
# [05/03/2023 09:57:05 INFO 140247015941952] Epoch[3] Batch [11000]#011Speed: 161533.83 samples/sec#011binary_classification_accuracy=0.986784#011binary_classification_cross_entropy=0.055266
# [05/03/2023 09:57:05 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=11000 train binary_classification_accuracy <score>=0.9867836560312698
# [05/03/2023 09:57:05 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=11000 train binary_classification_cross_entropy <loss>=0.055265575931848325
# [05/03/2023 09:57:11 INFO 140247015941952] Epoch[3] Batch [12000]#011Speed: 165056.80 samples/sec#011binary_classification_accuracy=0.986780#011binary_classification_cross_entropy=0.055282
# [05/03/2023 09:57:11 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=12000 train binary_classification_accuracy <score>=0.986780434963753
# [05/03/2023 09:57:11 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=12000 train binary_classification_cross_entropy <loss>=0.0552817778085512
# [05/03/2023 09:57:17 INFO 140247015941952] Epoch[3] Batch [13000]#011Speed: 165646.06 samples/sec#011binary_classification_accuracy=0.986805#011binary_classification_cross_entropy=0.055217
# [05/03/2023 09:57:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=13000 train binary_classification_accuracy <score>=0.9868050919160065
# [05/03/2023 09:57:17 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=13000 train binary_classification_cross_entropy <loss>=0.055217032694062876
# [05/03/2023 09:57:23 INFO 140247015941952] Epoch[3] Batch [14000]#011Speed: 163874.05 samples/sec#011binary_classification_accuracy=0.986818#011binary_classification_cross_entropy=0.055199
# [05/03/2023 09:57:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=14000 train binary_classification_accuracy <score>=0.986818155846011
# [05/03/2023 09:57:23 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, batch=14000 train binary_classification_cross_entropy <loss>=0.055199466495392674
# [05/03/2023 09:57:28 INFO 140247015941952] Epoch[3] Train-binary_classification_accuracy=0.986834
# [05/03/2023 09:57:28 INFO 140247015941952] Epoch[3] Train-binary_classification_cross_entropy=0.055135
# [05/03/2023 09:57:28 INFO 140247015941952] Epoch[3] Time cost=90.217
# [05/03/2023 09:57:28 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, train binary_classification_accuracy <score>=0.9868337269721303
# [05/03/2023 09:57:28 INFO 140247015941952] #quality_metric: host=algo-1, epoch=3, train binary_classification_cross_entropy <loss>=0.05513488817655796
# #metrics {"StartTime": 1683107758.7090673, "EndTime": 1683107848.9312038, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 90221.74119949341, "count": 1, "min": 90221.74119949341, "max": 90221.74119949341}}}
# [05/03/2023 09:57:28 INFO 140247015941952] #progress_metric: host=algo-1, completed 80.0 % of epochs
# #metrics {"StartTime": 1683107758.7094362, "EndTime": 1683107848.9315062, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 59255336.0, "count": 1, "min": 59255336, "max": 59255336}, "Total Batches Seen": {"sum": 59276.0, "count": 1, "min": 59276, "max": 59276}, "Max Records Seen Between Resets": {"sum": 14813834.0, "count": 1, "min": 14813834, "max": 14813834}, "Max Batches Seen Between Resets": {"sum": 14819.0, "count": 1, "min": 14819, "max": 14819}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/03/2023 09:57:28 INFO 140247015941952] #throughput_metric: host=algo-1, train throughput=164192.7090785506 records/second
# [05/03/2023 09:57:28 WARNING 140247015941952] Already bound, ignoring bind()
# [05/03/2023 09:57:28 WARNING 140247015941952] optimizer already initialized, ignoring...
# [05/03/2023 09:57:28 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_accuracy <score>=0.985
# [05/03/2023 09:57:28 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=0 train binary_classification_cross_entropy <loss>=0.06469149780273438
# [05/03/2023 09:57:35 INFO 140247015941952] Epoch[4] Batch [1000]#011Speed: 164854.73 samples/sec#011binary_classification_accuracy=0.987133#011binary_classification_cross_entropy=0.053829
# [05/03/2023 09:57:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=1000 train binary_classification_accuracy <score>=0.9871328671328672
# [05/03/2023 09:57:35 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=1000 train binary_classification_cross_entropy <loss>=0.05382851816152597
# [05/03/2023 09:57:41 INFO 140247015941952] Epoch[4] Batch [2000]#011Speed: 166210.94 samples/sec#011binary_classification_accuracy=0.986895#011binary_classification_cross_entropy=0.054577
# [05/03/2023 09:57:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=2000 train binary_classification_accuracy <score>=0.9868945527236381
# [05/03/2023 09:57:41 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=2000 train binary_classification_cross_entropy <loss>=0.054576681326771306
# [05/03/2023 09:57:47 INFO 140247015941952] Epoch[4] Batch [3000]#011Speed: 164419.83 samples/sec#011binary_classification_accuracy=0.986929#011binary_classification_cross_entropy=0.054354
# [05/03/2023 09:57:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=3000 train binary_classification_accuracy <score>=0.9869290236587804
# [05/03/2023 09:57:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=3000 train binary_classification_cross_entropy <loss>=0.054354155771496375
# [05/03/2023 09:57:53 INFO 140247015941952] Epoch[4] Batch [4000]#011Speed: 165433.92 samples/sec#011binary_classification_accuracy=0.986870#011binary_classification_cross_entropy=0.054495
# [05/03/2023 09:57:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=4000 train binary_classification_accuracy <score>=0.986870032491877
# [05/03/2023 09:57:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch
47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=13000 train binary_classification_accuracy <score>=0.9868761633720483
# [05/03/2023 09:58:47 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=13000 train binary_classification_cross_entropy <loss>=0.05457086121314361
# [05/03/2023 09:58:53 INFO 140247015941952] Epoch[4] Batch [14000]#011Speed: 164288.64 samples/sec#011binary_classification_accuracy=0.986870#011binary_classification_cross_entropy=0.054552
# [05/03/2023 09:58:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=14000 train binary_classification_accuracy <score>=0.9868702235554603
# [05/03/2023 09:58:53 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, batch=14000 train binary_classification_cross_entropy <loss>=0.05455170616082877
# [05/03/2023 09:58:58 INFO 140247015941952] Epoch[4] Train-binary_classification_accuracy=0.986885
# [05/03/2023 09:58:58 INFO 140247015941952] Epoch[4] Train-binary_classification_cross_entropy=0.054476
# [05/03/2023 09:58:58 INFO 140247015941952] Epoch[4] Time cost=89.902
# [05/03/2023 09:58:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, train binary_classification_accuracy <score>=0.9868848100411634
# [05/03/2023 09:58:58 INFO 140247015941952] #quality_metric: host=algo-1, epoch=4, train binary_classification_cross_entropy <loss>=0.05447631163912124
# #metrics {"StartTime": 1683107848.9312844, "EndTime": 1683107938.838999, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training"}, "Metrics": {"update.time": {"sum": 89907.11450576782, "count": 1, "min": 89907.11450576782, "max": 89907.11450576782}}}
# [05/03/2023 09:58:58 INFO 140247015941952] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1683107848.9318507, "EndTime": 1683107938.8392744, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 74069170.0, "count": 1, "min": 74069170, "max": 74069170}, "Total Batches Seen": {"sum": 74095.0, "count": 1, "min": 74095, "max": 74095}, "Max Records Seen Between Resets": {"sum": 14813834.0, "count": 1, "min": 14813834, "max": 14813834}, "Max Batches Seen Between Resets": {"sum": 14819.0, "count": 1, "min": 14819, "max": 14819}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [05/03/2023 09:58:58 INFO 140247015941952] #throughput_metric: host=algo-1, train throughput=164767.38845998692 records/second
# [05/03/2023 09:58:58 WARNING 140247015941952] wait_for_all_workers will not sync workers since the kv store is not running distributed
# #metrics {"StartTime": 1683107938.8390887, "EndTime": 1683107938.8398438, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training"}, "Metrics": {"finalize.time": {"sum": 0.2155303955078125, "count": 1, "min": 0.2155303955078125, "max": 0.2155303955078125}}}
# [05/03/2023 09:58:58 INFO 140247015941952] Saved checkpoint to "/tmp/tmpbp20rs1a/state-0001.params"
# [05/03/2023 09:58:58 INFO 140247015941952] Test data is not provided.
# #metrics {"StartTime": 1683107938.8399153, "EndTime": 1683107938.8764324, "Dimensions": {"Algorithm": "ipinsights", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 42.310476303100586, "count": 1, "min": 42.310476303100586, "max": 42.310476303100586}, "totaltime": {"sum": 453795.8459854126, "count": 1, "min": 453795.8459854126, "max": 453795.8459854126}}}
#
# 2023-05-03 09:59:17 Uploading - Uploading generated training model
# 2023-05-03 09:59:17 Completed - Training job completed
# Training seconds: 650
# Billable seconds: 650

# %% [markdown]
# If you see the message
#
#     > Completed - Training job completed
#
# at the bottom of the output logs then that means training successfully completed and the output of the SageMaker IP Insights model was stored in the specified output path. You can also view information about and the status of a training job using the AWS SageMaker console. Just click on the "Jobs" tab and select training job matching the training job name, below:

# %%
print(f"Training job name: {ip_insights.latest_training_job.job_name}")
# Out:
# Training job name: ipinsights-2023-05-03-09-47-14-417

# %% [markdown]
# ## 3 Inference
# -----
#
# Now that we have trained a SageMaker IP Insights model, we can deploy the model to an endpoint to start performing inference on data. In this case, that means providing it a `<user, IP address>` pair and predicting their compatability scores.
#
# We can create an inference endpoint using the SageMaker Python SDK `deploy()`function from the job we defined above. We specify the instance type where inference will be performed, as well as the initial number of instnaces to spin up. We recommend using the `ml.m5` instance as it provides the most memory at the lowest cost. Verify how large your model is in S3 and pick the instance type with the appropriate amount of memory.

# %% [markdown]
# ### 1. Creating Inference Endpoint

# %%
predictor = ip_insights.deploy(initial_instance_count=1, instance_type="ml.m5.xlarge")
# Out:
# INFO:sagemaker:Creating model with name: ipinsights-2023-05-03-10-05-44-800
# INFO:sagemaker:Creating endpoint-config with name ipinsights-2023-05-03-10-05-44-800
# INFO:sagemaker:Creating endpoint with name ipinsights-2023-05-03-10-05-44-800
# --------!

# %% [markdown]
# Congratulations, you now have a SageMaker IP Insights inference endpoint! You could start integrating this endpoint with your production services to start querying incoming requests for abnormal behavior.
#
# You can confirm the endpoint configuration and status by navigating to the "Endpoints" tab in the AWS SageMaker console and selecting the endpoint matching the endpoint name below:

# %%
print(f"Endpoint name: {predictor.endpoint}")
# Out:
# WARNING:sagemaker.deprecations:The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Endpoint name: ipinsights-2023-05-03-10-05-44-800

# %% [markdown]
# ### 2. Data Serialization/Deserialization
# We can pass data in a variety of formats to our inference endpoint. In this example, we will pass CSV-formmated data. Other available formats are JSON-formated and JSON Lines-formatted. We make use of the SageMaker Python SDK utilities: `csv_serializer` and `json_deserializer` when configuring the inference endpoint

# %%
from sagemaker.predictor import csv_serializer, json_deserializer

predictor.serializer = csv_serializer
predictor.deserializer = json_deserializer

# %% [markdown]
# Now that the predictor is configured, it is as easy as passing in a matrix of inference data.
# We can take a few samples from the simulated dataset above, so we can see what the output looks like.

# %%
#what does the train_df look like
print(train_df[:10])
train_df.count()
# Out:
#               user       ip_address           timestamp
# 61125     user_259  157.119.235.190 2018-11-06 04:58:05
# 1107985  user_3886    76.72.107.195 2018-11-08 16:48:46
# 2778339  user_9121    209.115.50.12 2018-11-08 03:20:20
# 1808248  user_5867    195.58.235.84 2018-11-10 10:54:36
# 1500486  user_5176    89.161.26.173 2018-11-10 02:22:50
# 1645313  user_5514   173.248.203.10 2018-11-04 02:14:06
# 1577958  user_5390  198.151.202.122 2018-11-04 06:04:30
# 1995249  user_6528   202.82.190.203 2018-11-08 22:17:00
# 2304698  user_7645    68.105.16.106 2018-11-07 07:07:58
# 2790275  user_9252      143.8.31.71 2018-11-10 13:36:40
# user          2116262
# ip_address    2116262
# timestamp     2116262
# dtype: int64

# %%
inference_data = [(data[0], data[1]) for data in train_df[:5].values]
predictor.predict(
    inference_data, initial_args={"ContentType": "text/csv", "Accept": "application/json"}
)
# Out:
# WARNING:sagemaker.deprecations:The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# {'predictions': [{'dot_product': 2.7837936878204346},
#   {'dot_product': 8.600976943969727},
#   {'dot_product': 4.100890159606934},
#   {'dot_product': 4.357046127319336},
#   {'dot_product': 4.356419563293457}]}

# %% [markdown]
# By default, the predictor will only output the `dot_product` between the learned IP address and the online resource (in this case, the user ID). The dot product summarizes the compatibility between the IP address and online resource. The larger the value, the more the algorithm thinks the IP address is likely to be used by the user. This compatability score is sufficient for most applications, as we can define a threshold for what we constitute as an anomalous score.
#
# However, more advanced users may want to inspect the learned embeddings and use them in further applications. We can configure the predictor to provide the learned embeddings by specifing the `verbose=True` parameter to the Accept heading. You should see that each 'prediction' object contains three keys: `ip_embedding`, `entity_embedding`, and `dot_product`.

# %%
predictor.predict(
    inference_data,
    initial_args={"ContentType": "text/csv", "Accept": "application/json; verbose=True"},
)
# Out:
# WARNING:sagemaker.deprecations:The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# {'predictions': [{'dot_product':
#     0.1303471177816391,
#     1.1711909770965576,
#     -0.30073872208595276,
#     -0.5084882378578186,
#     1.7164489030838013,
#     -1.1819826364517212,
#     -0.1932872086763382,
#     -1.237689733505249,
#     -2.165058135986328,
#     0.29972121119499207,
#     -0.027104776352643967,
#     0.6938799619674683,
#     0.04615185037255287,
#     0.5814090371131897,
#     0.34133219718933105,
#     -0.7773882150650024,
#     0.519595742225647,
#     -0.7186828851699829,
#     -2.3199689388275146,
#     0.18392722308635712,
#     0.12081550061702728,
#     0.42753148078918457,
#     -0.04395362734794617,
#     -0.9570738077163696,
#     -0.02346895821392536,
#     -0.41209086775779724,
#     -0.4473215937614441,
#     -0.47351107001304626,
#     0.5739852786064148,
#     1.8711016178131104,
#     -0.5199300050735474,
#     0.5325440168380737,
#     -0.01852230541408062,
#     -0.42206913232803345,
#     0.09019969403743744,
#     -0.09352967143058777,
#     0.18009530007839203,
#     -0.3012525141239166,
#     -0.7236387133598328,
#     0.889008641242981,
#     -0.4158063232898712,
#     1.6768983602523804,
#     0.689188539981842,
#     -1.3496347665786743,
#     -0.7138553261756897,
#     0.41292572021484375,
#     -0.6600148677825928,
#     0.22033250331878662,
#     -0.36777958273887634,
#     -1.1561402082443237,
#     0.3291000425815582,
#     0.5896794199943542,
#     -1.5967707633972168,
#     -0.9105144739151001,
#     0.12911640107631683,
#     1.3614537715911865,
#     -2.03536319732666,
#     0.8389961123466492,
#     -0.5749688148498535,
#     -0.5552271604537964,
#     0.1366603523492813,
#     -0.8261400461196899,
#     -0.6711059212684631,
#     -0.4914928674697876,
#     0.9675200581550598,
#     0.09473030269145966,
#     0.24858583509922028,
#     0.5172363519668579,
#     0.09970583766698837,
#     0.2672543227672577,
#     -0.45047494769096375,
#     -0.7286410331726074,
#     0.4780627489089966,
#     0.8744897246360779,
#     -0.3547936975955963,
#     -0.6951042413711548,
#     -1.596699595451355]}]}

# %% [markdown]
# ## Compute Anomaly Scores
# ----
# The `dot_product` output of the model provides a good measure of how compatible an IP address and online resource are. However, the range of the dot_product is unbounded. This means to be able to consider an event as anomolous we need to define a threshold. Such that when we score an event, if the dot_product is above the threshold we can flag the behavior as anomolous.However, picking a threshold can be more of an art, and a good threshold depends on the specifics of your problem and dataset.
#
# In the following section, we show how to pick a simple threshold by comparing the score distributions between known normal and malicious traffic:
# 1. We construct a test set of 'Normal' traffic;
# 2. Inject 'Malicious' traffic into the dataset;
# 3. Plot the distribution of dot_product scores for the model on 'Normal' trafic and the 'Malicious' traffic.
# 3. Select a threshold value which separates the normal distribution from the malicious traffic threshold. This value is based on your false-positive tolerance.
#
# ### 1. Construct 'Normal' Traffic Dataset
#
# We previously [created a test set](#3.-Create-training-and-test-dataset) from our simulated Apache access logs dataset. We use this test dataset as the 'Normal' traffic in the test case.

# %%
test_df.head()
# Out:
#       user      ip_address           timestamp
# 4   user_0   94.125.50.187 2018-11-13 12:07:31
# 14  user_0  103.102.91.142 2018-11-13 08:00:12
# 16  user_0   103.102.43.72 2018-11-13 16:11:54
# 874  user_63    123.109.42.30 2018-11-11 16:13:59
# 876  user_63    116.202.4.110 2018-11-11 01:10:47
# 880  user_63    116.202.28.61 2018-11-12 11:36:05
# 881  user_63    123.109.79.29 2018-11-11 22:40:08
# 882  user_63   123.109.118.19 2018-11-12 15:35:58
# 885  user_63   123.109.127.87 2018-11-13 23:45:50

# %% [markdown]
# ### 2. Inject Malicious Traffic
# If we had a dataset with enough real malicious activity, we would use that to determine a good threshold. Those are hard to come by. So instead, we simulate malicious web traffic that mimics a realistic attack scenario.
#
# We take a set of user accounts from the test set and randomly generate IP addresses. The users should not have used these IP addresses during training. This simulates an attacker logging in to a user account without knowledge of their IP history.

# %%
import numpy as np
from generate_data import draw_ip


def score_ip_insights(predictor, df):
    def get_score(result):
        """Return the negative to the dot product of the predictions from the model."""
        return [-prediction["dot_product"] for prediction in result["predictions"]]

    df = df[["user", "ip_address"]]
    result = predictor.predict(df.values)
    return get_score(result)


def create_test_case(train_df, test_df, num_samples, attack_freq):
    """Creates a test case from provided train and test data frames.

    This generates test case for accounts that are both in training and testing data sets.

    :param train_df: (panda.DataFrame with columns ['user', 'ip_address']) training DataFrame
    :param test_df: (panda.DataFrame with columns ['user', 'ip_address']) testing DataFrame
    :param num_samples: (int) number of test samples to use
    :param attack_freq: (float) the ratio of negative_samples:positive_samples to generate for test case
    :return: DataFrame with both good and bad traffic, with labels
    """
    # Get all possible accounts. The IP Insights model can only make predictions on users it has seen in training
    # Therefore, filter the test dataset for unseen accounts, as their results will not mean anything.
    valid_accounts = set(train_df["user"])
    valid_test_df = test_df[test_df["user"].isin(valid_accounts)]

    good_traffic = valid_test_df.sample(num_samples, replace=False)
    good_traffic = good_traffic[["user", "ip_address"]]
    good_traffic["label"] = 0

    # Generate malicious traffic
    num_bad_traffic = int(num_samples * attack_freq)
    bad_traffic_accounts = np.random.choice(
        list(valid_accounts), size=num_bad_traffic, replace=True
    )
    bad_traffic_ips = [draw_ip() for i in range(num_bad_traffic)]
    bad_traffic = pd.DataFrame({"user": bad_traffic_accounts, "ip_address": bad_traffic_ips})
    bad_traffic["label"] = 1

    # All traffic labels are: 0 for good traffic; 1 for bad traffic.
    all_traffic = good_traffic.append(bad_traffic)

    return all_traffic

# %% [markdown]
# #### Sample test cases created with label, [0]: Good Traffic and [1]: Bad traffic

# %%
NUM_SAMPLES = 100000
test_case = create_test_case(train_df, test_df, num_samples=NUM_SAMPLES, attack_freq=1)
test_case.head()
# Out:
# /tmp/ipykernel_10826/3946420561.py:45: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_traffic = good_traffic.append(bad_traffic)
#               user       ip_address  label
# 813045   user_2982   194.116.99.191      0
# 2665609  user_8830   79.177.205.239      0
# 519104   user_1882      103.6.87.10      0
# 2242248  user_7504    183.91.74.126      0
# 1332922  user_4423  207.250.225.152      0

# %%
test_case_scores = score_ip_insights(predictor, test_case)
# Out:
# WARNING:sagemaker.deprecations:The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
print(f"The length of test case scores is: {len(test_case_scores)}")
# Out:
# The length of test case scores is: 200000

# %%
#Combining Score with Entity and IP
print(len(test_case))
# Out:
# 200000

# %% [markdown]
# #### Getting Scores for specific user e.g. user_63
#
# With the information below answer the following questions:
# 1. How many good traffic and bad traffic are there for user_63
# 2. How can we predict the "right" threshold to set with the scores we have.
#
# **Threshold** define when an analyst should be alerted with "bad" traffic

# %%
#Sample test cases for specific user e.g. user_63
user_63 = test_case.loc[test_case['user'].isin(['user_63'])]
print(user_63)
# Out:
#           user       ip_address  label     scores
# 763    user_63   123.109.148.81      0  -0.696969
# 8833   user_63     169.1.44.222      1  11.271156
# 12932  user_63  179.223.202.163      1   7.962625
# 16446  user_63   74.204.244.119      1  12.853996
# 34168  user_63   93.183.214.219      1   6.305768
# 58629  user_63    185.37.37.157      1   3.312937
# 62970  user_63    27.54.209.185      1   3.145485
# 75787  user_63  203.246.161.197      1   4.400783
# 85592  user_63   223.22.237.249      1   5.611652
# 87452  user_63     66.253.44.73      1   4.665980
# 90149  user_63   182.71.100.155      1   9.159926

# %%
#Identify total count of each label (1:Bad Traffic, 2:Good Traffic) for user_63
user_63.groupby('label')['label'].count()
# Out:
# label
# 0     1
# 1    10
# Name: label, dtype: int64

# %%
#Combine test_case with test_case_score
test_case["scores"] = test_case_scores
test_case.head()
user_63_merged = test_case.loc[test_case['user'].isin(['user_63'])]

# %%
print(user_63_merged)
# Out:
#           user       ip_address  label     scores
# 763    user_63   123.109.148.81      0  -0.696969
# 8833   user_63     169.1.44.222      1  11.271156
# 12932  user_63  179.223.202.163      1   7.962625
# 16446  user_63   74.204.244.119      1  12.853996
# 34168  user_63   93.183.214.219      1   6.305768
# 58629  user_63    185.37.37.157      1   3.312937
# 62970  user_63    27.54.209.185      1   3.145485
# 75787  user_63  203.246.161.197      1   4.400783
# 85592  user_63   223.22.237.249      1   5.611652
# 87452  user_63     66.253.44.73      1   4.665980
# 90149  user_63   182.71.100.155      1   9.159926

# %%
# Get the score for user_63
user_63_scores = user_63_merged["scores"]
print(f"{user_63_scores}")
# Out:
# 763      -0.696969
# 8833     11.271156
# 12932     7.962625
# 16446    12.853996
# 34168     6.305768
# 58629     3.312937
# 62970     3.145485
# 75787     4.400783
# 85592     5.611652
# 87452     4.665980
# 90149     9.159926
# Name: scores, dtype: float64

# %%
# Get total num of row for user_63_scores
NUM_SAMPLES_USER_63=len(user_63_scores)
print(f" The length of sample for user_63 scores is: {NUM_SAMPLES_USER_63}")
# Out:
#  The length of sample for user_63 scores is: 11

# %% [markdown]
# ### 3. Plot Distribution
#
# Now, we plot the distribution of scores. Looking at this distribution will inform us on where we can set a good threshold, based on our risk tolerance.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

n, x = np.histogram(test_case_scores[:NUM_SAMPLES], bins=100, density=True)
plt.plot(x[1:], n)

n, x = np.histogram(test_case_scores[NUM_SAMPLES:], bins=100, density=True)
plt.plot(x[1:], n)

plt.legend(["Normal IP - Legitimate events", "Random IP - Malicious events"])
plt.xlabel("IP Insights Score")
plt.ylabel("Frequency")

plt.figure()

# %% [markdown]
# ### 4. Selecting a Good Threshold
#
# As we see in the figure above, there is a clear separation between normal traffic and random traffic.
# We could select a threshold depending on the application.
#
# - If we were working with low impact decisions, such as whether to ask for another factor or authentication during login, we could use a `threshold = 0.0`. This would result in catching more true-positives, at the cost of more false-positives.
#
# - If our decision system were more sensitive to false positives, we could choose a larger threshold, such as `threshold = 10.0`. That way if we were sending the flagged cases to manual investigation, we would have a higher confidence that the acitivty was suspicious.

# %% [markdown]
# #### Understanding Threshold, Recall, Precision
#
# |TP|FP|
# |--|--|
# |TN|FN|
#
# - TP = Alarm Rang, Real Security Event
# - FP = Alarm Rang, Not a Security Event
# - TN = Alarm did not rang, Not a Security Event
# - FN = Alarm did not rang, Real Security Event

# %%
threshold = 0.0

flagged_cases = test_case[np.array(test_case_scores) > threshold]

num_flagged_cases = len(flagged_cases)
num_true_positives = len(flagged_cases[flagged_cases["label"] == 1])
num_false_positives = len(flagged_cases[flagged_cases["label"] == 0])
num_all_positives = len(test_case.loc[test_case["label"] == 1])

print(f"When threshold is set to: {threshold}")
print(f"Total of {num_flagged_cases} flagged cases")
print(f"Total of {num_true_positives} flagged cases are true positives")
print(f"True Positive Rate: {num_true_positives / float(num_flagged_cases)}")
print(f"Recall: {num_true_positives / float(num_all_positives)}")
print(f"Precision: {num_true_positives / float(num_flagged_cases)}")
# Out:
# When threshold is set to: 0.0
# Total of 103000 flagged cases
# Total of 98469 flagged cases are true positives
# True Positive Rate: 0.9560097087378641
# Recall: 0.98469
# Precision: 0.9560097087378641

# %% [markdown]
# ## Epilogue
# ----
#
# In this notebook, we have showed how to configure the basic training, deployment, and usage of the Amazon SageMaker IP Insights algorithm. All SageMaker algorithms come with support for two additional services that make optimizing and using the algorithm that much easier: Automatic Model Tuning and Batch Transform service.
#
#
# ### Amazon SageMaker Automatic Model Tuning
# The results above were based on using the default hyperparameters of the SageMaker IP Insights algorithm. If we wanted to improve the model's performance even more, we can use [Amazon SageMaker Automatic Model Tuning](https://docs.aws.amazon.com/sagemaker/latest/dg/automatic-model-tuning.html) to automate the process of finding the hyperparameters.
#
# #### Validation Dataset
# Previously, we separated our dataset into a training and test set to validate the performance of a single IP Insights model. However, when we do model tuning, we train many IP Insights models in parallel. If we were to use the same test dataset to select the best model, we bias our model selection such that we don't know if we selected the best model in general, or just the best model for that particular dateaset.
#
# Therefore, we need to separate our test set into a validation dataset and a test dataset. The validation dataset is used for model selection. Then once we pick the model with the best performance, we evaluate it the winner on a test set just as before.
#
# #### Validation Metrics
# For SageMaker Automatic Model Tuning to work, we need an objective metric which determines the performance of the model we want to optimize. Because SageMaker IP Insights is an usupervised algorithm, we do not have a clearly defined metric for performance (such as percentage of fraudulent events discovered).
#
# We allow the user to provide a validation set of sample data (same format as training data bove) through the `validation` channel. We then fix the negative sampling strategy to use `random_negative_sampling_rate=1` and `shuffled_negative_sampling_rate=0` and generate a validation dataset by assigning corresponding labels to the real and simulated data. We then calculate the model's `descriminator_auc` metric. We do this by taking the model's predicted labels and the 'true' simulated labels and compute the Area Under ROC Curve (AUC) on the model's performance.
#
# We set up the `HyperParameterTuner` to maximize the `discriminator_auc` on the validation dataset. We also need to set the search space for the hyperparameters. We give recommended ranges for the hyperparmaeters in the [Amazon SageMaker IP Insights (Hyperparameters)](https://docs.aws.amazon.com/sagemaker/latest/dg/ip-insights-hyperparameters.html) documentation.

# %%
test_df["timestamp"].describe()
# Out:
# /tmp/ipykernel_5094/1189181443.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   test_df["timestamp"].describe()
# count                  958825
# unique                 252729
# top       2018-11-11 09:45:07
# freq                       16
# first     2018-11-11 00:00:01
# last      2018-11-14 00:00:00
# Name: timestamp, dtype: object

# %% [markdown]
# The test set we constructed above spans 3 days. We reserve the first day as the validation set and the subsequent two days for the test set.

# %%
time_partition = (
    datetime(2018, 11, 13, tzinfo=pytz.FixedOffset(0))
    if num_time_zones > 1
    else datetime(2018, 11, 13)
)

validation_df = test_df[test_df["timestamp"] < time_partition]
test_df = test_df[test_df["timestamp"] >= time_partition]

valid_data = validation_df.to_csv(index=False, header=False, columns=["user", "ip_address"])

# %% [markdown]
# We then upload the validation data to S3 and specify it as the validation channel.

# %%
# Upload data to S3 key
validation_data_file = "valid.csv"
key = os.path.join(prefix, "validation", validation_data_file)
boto3.resource("s3").Bucket(bucket).Object(key).put(Body=valid_data)
s3_valid_data = f"s3://{bucket}/{key}"

print(f"Validation data has been uploaded to: {s3_valid_data}")

# Configure SageMaker IP Insights Input Channels
input_data = {"train": s3_train_data, "validation": s3_valid_data}
# Out:
# Validation data has been uploaded to: s3://aseansecaiml-25apr2023/sagemaker/ipinsights-tutorial/validation/valid.csv

# %%
from sagemaker.tuner import HyperparameterTuner, IntegerParameter

# Configure HyperparameterTuner
ip_insights_tuner = HyperparameterTuner(
    estimator=ip_insights,  # previously-configured Estimator object
    objective_metric_name="validation:discriminator_auc",
    hyperparameter_ranges={"vector_dim": IntegerParameter(64, 1024)},
    max_jobs=4,
    max_parallel_jobs=2,
)

# Start hyperparameter tuning job
ip_insights_tuner.fit(input_data, include_cls_metadata=False)
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: ipinsights-230427-0926
# ..............................

# %%
# Wait for all the jobs to finish
ip_insights_tuner.wait()

# Visualize training job results
ip_insights_tuner.analytics().dataframe()
# Out:
# !
#    vector_dim                      TrainingJobName TrainingJobStatus  \
# 0       677.0  ipinsights-230427-0926-004-2b5506b0         Completed
# 1       332.0  ipinsights-230427-0926-003-f38d5fd8         Completed
# 2       769.0  ipinsights-230427-0926-002-5e4a0797         Completed
# 3       485.0  ipinsights-230427-0926-001-bc568f65         Completed
#
#    FinalObjectiveValue         TrainingStartTime           TrainingEndTime  \
# 0             0.989283 2023-04-27 09:41:08+00:00 2023-04-27 09:51:02+00:00
# 1             0.990640 2023-04-27 09:41:06+00:00 2023-04-27 09:50:30+00:00
# 2             0.988644 2023-04-27 09:27:54+00:00 2023-04-27 09:40:29+00:00
# 3             0.990173 2023-04-27 09:27:50+00:00 2023-04-27 09:40:00+00:00
#
#    TrainingElapsedTimeSeconds
# 0                       594.0
# 1                       564.0
# 2                       755.0
# 3                       730.0

# %%
# Deploy best model
tuned_predictor = ip_insights_tuner.deploy(
    initial_instance_count=1,
    instance_type="ml.m4.xlarge",
    serializer=csv_serializer,
    deserializer=json_deserializer,
)
# Out:
# 2023-04-27 09:50:32 Starting - Found matching resource for reuse
# 2023-04-27 09:50:32 Downloading - Downloading input data
# 2023-04-27 09:50:32 Training - Training image download completed. Training in progress.
# 2023-04-27 09:50:32 Uploading - Uploading generated training model
# 2023-04-27 09:50:32 Completed - Resource released due to keep alive period expiry
# INFO:sagemaker:Creating model with name: ipinsights-2023-04-28-02-55-53-972
# INFO:sagemaker:Creating endpoint-config with name ipinsights-230427-0926-003-f38d5fd8
# INFO:sagemaker:Creating endpoint with name ipinsights-230427-0926-003-f38d5fd8
# ---------!

# %%
# Make a prediction against the SageMaker endpoint
tuned_predictor.predict(
    inference_data, initial_args={"ContentType": "text/csv", "Accept": "application/json"}
)
# Out:
# WARNING:sagemaker.deprecations:The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# {'predictions': [{'dot_product': 4.1678667068481445},
#   {'dot_product': -10.637112617492676},
#   {'dot_product': 2.4053802490234375},
#   {'dot_product': 2.9765799045562744},
#   {'dot_product': 3.9288673400878906}]}

# %%
# Visualise the anomaly
test_case_scores_tuned = score_ip_insights(predictor, test_case)
# Out:
# WARNING:sagemaker.deprecations:The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# We should have the best performing model from the training job! Now we can determine thresholds and make predictions just like we did with the inference endpoint [above](#Inference).

# %% [markdown]
# ### Batch Transform
# Let's say we want to score all of the login events at the end of the day and aggregate flagged cases for investigators to look at in the morning. If we store the daily login events in S3, we can use IP Insights with [Amazon SageMaker Batch Transform](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-batch.html) to run inference and store the IP Insights scores back in S3 for future analysis.
#
# Below, we take the training job from before and evaluate it on the validation data we put in S3.

# %%
transformer = ip_insights.transformer(instance_count=1, instance_type="ml.m4.xlarge")

transformer.transform(s3_valid_data, content_type="text/csv", split_type="Line")
# Out:
# INFO:sagemaker:Creating model with name: ipinsights-2023-04-28-03-38-42-694
# INFO:sagemaker:Created S3 bucket: sagemaker-ap-southeast-1-817562650497
# INFO:sagemaker:Creating transform job with name: ipinsights-2023-04-28-03-38-43-430
# .........

# %%
#Read S3 Files
import boto3
import sys
from io import StringIO
import pandas as pd

# Initialize boto3 to use S3 resource
s3_resource = boto3.resource('s3')
def readFile(bucket, key):
    try:

        df = []   # Initializing empty list of dataframes

        # Get the object from the S3 Bucket
        s3_object = s3_resource.Object(
            bucket_name=bucket, 
            key=key
        )

        # Get the response from get_object()
        s3_response = s3_object.get()

        # Get the Body object from the S3 get_object() response
        s3_object_body = s3_response.get('Body')

        # Read the data in bytes format and convert it to string
        content_str = s3_object_body.read().decode()
        #print(content_str)
        df = pd.read_csv(StringIO(content_str), sep=",", header=None)
        return df

    except s3_resource.meta.client.exceptions.NoSuchBucket as e:
        # S3 Bucket does not exist
        print('NO SUCH BUCKET')
        print(e)

    except s3_resource.meta.client.exceptions.NoSuchKey as e:
        # Object does not exist in the S3 Bucket
        print('NO SUCH KEY')
        print(e)

# %%
df = readFile(bucket, key)
df.head()
# Out:
#      users               IP
# 0  user_63    117.197.31.85
# 1  user_63  117.196.121.229
# 2  user_63   117.195.150.50
# 3  user_63    107.181.81.80
# 4  user_63   107.181.96.198

# %%
# Wait for Transform Job to finish
transformer.wait()
# Out:
# ..............................
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# [04/28/2023 03:46:24 INFO 139744972494656] loaded entry point class algorithm.serve.server_config:config_api
# [04/28/2023 03:46:24 INFO 139744972494656] loading entry points
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator application/x-ndarray for content type ('application/x-ndarray', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator text/csv for content type ('text/csv', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] loaded request iterator application/json
# [04/28/2023 03:46:24 INFO 139744972494656] loaded request iterator application/jsonlines
# [04/28/2023 03:46:24 INFO 139744972494656] loaded request iterator text/csv
# [04/28/2023 03:46:24 INFO 139744972494656] loaded response encoder application/json
# [04/28/2023 03:46:24 INFO 139744972494656] loaded response encoder application/jsonlines
# [04/28/2023 03:46:24 INFO 139744972494656] loaded entry point class algorithm:model
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator application/x-ndarray for content type ('application/x-ndarray', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator text/csv for content type ('text/csv', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] Number of server workers: 4
# [04/28/2023 03:46:24 INFO 139744972494656] loaded entry point class algorithm.serve.server_config:config_api
# [04/28/2023 03:46:24 INFO 139744972494656] loading entry points
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator application/x-ndarray for content type ('application/x-ndarray', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator text/csv for content type ('text/csv', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] loaded request iterator application/json
# [04/28/2023 03:46:24 INFO 139744972494656] loaded request iterator application/jsonlines
# [04/28/2023 03:46:24 INFO 139744972494656] loaded request iterator text/csv
# [04/28/2023 03:46:24 INFO 139744972494656] loaded response encoder application/json
# [04/28/2023 03:46:24 INFO 139744972494656] loaded response encoder application/jsonlines
# [04/28/2023 03:46:24 INFO 139744972494656] loaded entry point class algorithm:model
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator application/x-ndarray for content type ('application/x-ndarray', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] Loaded iterator creator text/csv for content type ('text/csv', '1.0')
# [04/28/2023 03:46:24 INFO 139744972494656] Number of server workers: 4
# [04/28/2023 03:46:24 INFO 139744972494656] loading model...
# [04/28/2023 03:46:24 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:24 INFO 139744972494656] nvidia-smi: took 0.035 seconds to run.
# [04/28/2023 03:46:24 INFO 139744972494656] nvidia-smi identified 0 GPUs.
# [04/28/2023 03:46:24 INFO 139744972494656] Number of GPUs being used: 0
# [04/28/2023 03:46:24 INFO 139744972494656] ...model loaded.
# [2023-04-28 03:46:24 +0000] [1] [INFO] Starting gunicorn 20.1.0
# [2023-04-28 03:46:24 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2023-04-28 03:46:24 +0000] [1] [INFO] Using worker: sync
# [2023-04-28 03:46:24 +0000] [55] [INFO] Booting worker with pid: 55
# [2023-04-28 03:46:24 +0000] [64] [INFO] Booting worker with pid: 64
# [04/28/2023 03:46:24 INFO 139744972494656] loading model...
# [04/28/2023 03:46:24 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:24 INFO 139744972494656] nvidia-smi: took 0.035 seconds to run.
# [04/28/2023 03:46:24 INFO 139744972494656] nvidia-smi identified 0 GPUs.
# [04/28/2023 03:46:24 INFO 139744972494656] Number of GPUs being used: 0
# [04/28/2023 03:46:24 INFO 139744972494656] ...model loaded.
# [2023-04-28 03:46:24 +0000] [1] [INFO] Starting gunicorn 20.1.0
# [2023-04-28 03:46:24 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2023-04-28 03:46:24 +0000] [1] [INFO] Using worker: sync
# [2023-04-28 03:46:24 +0000] [55] [INFO] Booting worker with pid: 55
# [2023-04-28 03:46:24 +0000] [64] [INFO] Booting worker with pid: 64
# [2023-04-28 03:46:24 +0000] [73] [INFO] Booting worker with pid: 73
# [2023-04-28 03:46:24 +0000] [82] [INFO] Booting worker with pid: 82
# [2023-04-28 03:46:24 +0000] [73] [INFO] Booting worker with pid: 73
# [2023-04-28 03:46:24 +0000] [82] [INFO] Booting worker with pid: 82
# #metrics {"StartTime": 1682653584.5368912, "EndTime": 1682653586.1687398, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"execution_parameters.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1682653584.5368912, "EndTime": 1682653586.1687398, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"execution_parameters.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# [04/28/2023 03:46:27 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:27 INFO 139744972494656] Number of GPUs being used: 0
# [04/28/2023 03:46:27 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:27 INFO 139744972494656] Number of GPUs being used: 0
# [04/28/2023 03:46:27 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:27 INFO 139744972494656] Number of GPUs being used: 0
# [04/28/2023 03:46:27 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:27 INFO 139744972494656] Number of GPUs being used: 0
# [04/28/2023 03:46:27 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:27 INFO 139744972494656] Number of GPUs being used: 0
# [04/28/2023 03:46:27 WARNING 139744972494656] Requesting context without setting the requested num of gpus. Using 'auto'
# [04/28/2023 03:46:27 INFO 139744972494656] Number of GPUs being used: 0
# 2023-04-28T03:46:26.174:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# #metrics {"StartTime": 1682653584.5368912, "EndTime": 1682653589.6775644, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1682653584.5368912, "EndTime": 1682653589.6775644, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1682653584.5368912, "EndTime": 1682653591.0188155, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1682653586.1689165, "EndTime": 1682653591.0934873, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1682653584.5368912, "EndTime": 1682653591.0188155, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1682653586.1689165, "EndTime": 1682653591.0934873, "Dimensions": {"Algorithm": "IPInsightsModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}

# %%
print(f"Batch Transform output is at: {transformer.output_path}")
# Out:
# Batch Transform output is at: s3://sagemaker-ap-southeast-1-817562650497/ipinsights-2023-04-28-03-38-43-430

# %%
#List all the files in S3
s3 = boto3.resource('s3')
my_bucket = s3.Bucket("sagemaker-ap-southeast-1-817562650497")

for my_bucket_object in my_bucket.objects.all():
    print(f"{my_bucket_object.key}\n")
    key = my_bucket_object.key
    df = readFile("sagemaker-ap-southeast-1-817562650497",key)
# Out:
# ipinsights-2023-04-28-03-38-43-430/valid.csv.out

# %%
df.head()
# Out:
#                                 users  IP
# 0  {"dot_product":-0.190504431724548} NaN
# 1   {"dot_product":1.138126730918884} NaN
# 2    {"dot_product":0.56033170223236} NaN
# 3   {"dot_product":3.613718271255493} NaN
# 4   {"dot_product":2.987053155899048} NaN

# %% [markdown]
# ### Stop and Delete the Endpoint
# If you are done with this model, then we should delete the endpoint before we close the notebook. Or else you will continue to pay for the endpoint while it is running.
#
# To do so execute the cell below. Alternately, you can navigate to the "Endpoints" tab in the SageMaker console, select the endpoint with the name stored in the variable endpoint_name, and select "Delete" from the "Actions" dropdown menu.

# %%
tuned_predictor.delete_model()
tuned_predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting model with name: ipinsights-2023-04-28-02-55-53-972
# INFO:sagemaker:Deleting endpoint configuration with name: ipinsights-230427-0926-003-f38d5fd8
# INFO:sagemaker:Deleting endpoint with name: ipinsights-230427-0926-003-f38d5fd8

# %%
predictor.delete_model()
predictor.delete_endpoint()
# Out:
# INFO:sagemaker:Deleting model with name: ipinsights-2023-04-26-09-55-52-731
# INFO:sagemaker:Deleting endpoint configuration with name: ipinsights-2023-04-26-09-55-52-731
# INFO:sagemaker:Deleting endpoint with name: ipinsights-2023-04-26-09-55-52-731

# %%
transformer.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: ipinsights-2023-04-28-03-38-42-694
